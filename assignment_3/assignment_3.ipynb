# %%
import pandas as pd
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import linear_model
from sklearn import svm
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import model_selection
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.model_selection import cross_validate
import datetime
import matplotlib.pyplot as plt
import spacy

# %%
nlp= spacy.load('en')
df= pd.read_csv("C:\\Users\\soura\\Downloads\\Amazon scrape\\Amazon scrape\\output.csv")
print(df)
# Out:
#                                                   title  \
# 0     Quality made and a fantastic deal!  Let me sho...
# 1     Miniature in size & price, but big on light ou...
# 2                      Great for the kids while Camping
# 3                                 Heavy Duty and Bright
# 4                                     Small, but mighty
# 5                                    small but powerful
# 6                                  One Bright, One Dim!
# 7                  Great Flashlights in a small package
# 8                                 one worked, one didnt
# 9                Fantastic Little Flashlight, Except...
# 10                             Not happy with modes!!!!
# 11           Surprisingly cool light and a great value!
# 12                             One for the price of two
# 13                          love these mini flashlights
# 14                             Very durable flashlights
# 15                      Not great, but worth the price.
# 16    These flashlights are not actually 300lumens. ...
# 17    Bright, well made. But wait for a sale to buy ...
# 18           and the illumination is great for the size
# 19                                compact and practical
# 20                         These work wonderfully well!
# 21           Great light, rechargeable battery friendly
# 22    Seemed high quality, power/selector button is ...
# 23    Best damn little 5 buck flashlight for EDC I l...
# 24                      Great lights for a great price.
# 25                                     Absolute Garbage
# 26                           You get what you paid for.
# 27                               Looks can be deceiving
# 28                  Delighted with this 6-pack of small
# 29    Great for the price, but not for your “main” l...
# ...                                                 ...
# 1282                                        Three Stars
# 1283                   Product switching going on here.
# 1284                                          Two Stars
# 1285                              Don't buy. Unreliable
# 1286                                        Three Stars
# 1287                             Great item as expected
# 1288                                         Five Stars
# 1289                                        Three Stars
# 1290                                           One Star
# 1291                                           One Star
# 1292                                         Five Stars
# 1293                                          Thank you
# 1294  One unit works great. It will be good for my t...
# 1295                   Not as bright as the compitition
# 1296                                           One Star
# 1297                          THis is no way 300 lumens
# 1298                   Bought 4 of these lights all DOA
# 1299                                 Good for the price
# 1300                            one works the ot doesnt
# 1301                               Defective. Don’t buy
# 1302                                         Four Stars
# 1303                                           One Star
# 1304  for $10 i guess it's barely acceptable. but an...
# 1305                                           No focus
# 1306                                           One Star
# 1307                                   Save your money.
# 1308  I bought 2 and they worked great for 2-3 weeks...
# 1309                   Product switching going on here.
# 1310                           sounds better than it is
# 1311  Failed Flashlight 4 months old and no refund o...
#
#                                                  review              rating  \
# 0      These Rockbirds LED Flashlights I bought came...  5.0 out of 5 stars
# 1     Given my many prior, poor experiences with sev...  4.0 out of 5 stars
# 2     Even though, the wide angle gives a decent spr...  3.0 out of 5 stars
# 3      These are good quality tactical flashlights. ...  5.0 out of 5 stars
# 4     These ended up being very handy, but I didn't ...  4.0 out of 5 stars
# 5     These are small enough to carry in a purse or ...  5.0 out of 5 stars
# 6     Handy little flashlights and I thought the cli...  4.0 out of 5 stars
# 7     Don't be fooled by their small appearance they...  5.0 out of 5 stars
# 8     i gave it 3 stars because only one of the flas...  3.0 out of 5 stars
# 9     Really love these little flashlights, they're ...  4.0 out of 5 stars
# 10    I ordered similar lights to this in the past.....  2.0 out of 5 stars
# 11    This is my new EDC replacing the Tank007 703. ...  5.0 out of 5 stars
# 12    Opened the box, grabbed one of the flashlights...  1.0 out of 5 stars
# 13    Great deal for a pair of mini flashlights.  Ve...  5.0 out of 5 stars
# 14    These flashlights work really well. The are he...  5.0 out of 5 stars
# 15    These flashlights aren't as bright as I expect...  4.0 out of 5 stars
# 16    These flashlights are not actually 300lumens. ...  2.0 out of 5 stars
# 17    Very well made aluminium tube and very bright....  4.0 out of 5 stars
# 18    These are very small flashlights. They feel ve...  5.0 out of 5 stars
# 19    I always like to keep a small flashlight in my...  5.0 out of 5 stars
# 20    We often need to head outdoors with no prior w...  5.0 out of 5 stars
# 21    These are very lightweight and last forever on...  5.0 out of 5 stars
# 22    These seem solid and good quality. However aft...  1.0 out of 5 stars
# 23    Best damn little 5 buck flashlight for EDC I l...  5.0 out of 5 stars
# 24    These mini LED flashlights are perfect for my ...  5.0 out of 5 stars
# 25    I bought these  flashlights to keep in the glo...  1.0 out of 5 stars
# 26    It is a small and cheap LED flashlight, I actu...  4.0 out of 5 stars
# 27    At first I was going to give it 1 star....Upon...  5.0 out of 5 stars
# 28    Delighted with this 6-pack of small, VERY brig...  5.0 out of 5 stars
# 29    Considering how little it costs for two of the...  4.0 out of 5 stars
# ...                                                 ...                 ...
# 1282                                    Not as expected  3.0 out of 5 stars
# 1283  ordered 1 light i was the 3 seting hi low and ...  1.0 out of 5 stars
# 1284             Not as bright as i thought it would be  2.0 out of 5 stars
# 1285                                 One does not work.  1.0 out of 5 stars
# 1286                            GREAT LITTLE FLASH LITE  3.0 out of 5 stars
# 1287                             Great item as expected  5.0 out of 5 stars
# 1288                           work great, super handy.  5.0 out of 5 stars
# 1289                                    NOT REAL BRIGHT  3.0 out of 5 stars
# 1290      DOA and this item is not eligible for return!  1.0 out of 5 stars
# 1291                                        terrible！！！  1.0 out of 5 stars
# 1292                                        Great light  5.0 out of 5 stars
# 1293                               Thank you very much.  5.0 out of 5 stars
# 1294  I know they were not expensive. One unit works...  1.0 out of 5 stars
# 1295  The heads are looseThe LED is most lokely not ...  2.0 out of 5 stars
# 1296  Ridiculous that it doesn't come with a battery...  1.0 out of 5 stars
# 1297  The light stopped working after a little over ...  1.0 out of 5 stars
# 1298  I received 4 of these flashlights last week, n...  1.0 out of 5 stars
# 1299  Great for price but unfortunately doesn't have...  4.0 out of 5 stars
# 1300    1 works fine .  the other blinks intermittently  1.0 out of 5 stars
# 1301  I was VERY disappointed with these flashlights...  1.0 out of 5 stars
# 1302                                good for the price.  4.0 out of 5 stars
# 1303       Already no longer working after minimal use.  1.0 out of 5 stars
# 1304  fairly dim.also you have to adjust the tension...  2.0 out of 5 stars
# 1305  Nice enough light but adjustable focus zoom ju...  2.0 out of 5 stars
# 1306  One DOA, second one can't use button to turn l...  1.0 out of 5 stars
# 1307  Works, but isn't worth the  price.Save your mo...  2.0 out of 5 stars
# 1308  I bought 2 and they worked great for 2-3 weeks...  1.0 out of 5 stars
# 1309  Ordered one of these lights as a test purchase...  1.0 out of 5 stars
# 1310  This item takes a long time to ship, the light...  1.0 out of 5 stars
# 1311  Bought 3 of these and so far one has failed on...  1.0 out of 5 stars
#
#                       author review_date
# 0                  GardenGuy    4-Mar-17
# 1                        NSB   10-Feb-18
# 2                       Snax    7-Nov-17
# 3                       jack    7-Mar-17
# 4                        JTL   13-Sep-17
# 5             Darlene Sharpe   16-Mar-17
# 6                       Nalo   25-Aug-17
# 7                   Minnchic    7-Apr-17
# 8                     Olivia   11-Dec-17
# 9         The Great Buzzwami   30-Apr-17
# 10    BillyBobBooooooJohnson   10-Dec-17
# 11            Chris Hoekstra   20-Dec-12
# 12                        JJ   29-Aug-17
# 13           paintednightsky   27-Apr-17
# 14                     Kelly    6-Apr-17
# 15                      Kris   29-Aug-17
# 16                   Matthew   30-Jun-17
# 17                DaytonaDan   25-Apr-17
# 18           Amazon Customer    6-Jan-17
# 19               electrolytz    6-Apr-17
# 20            WI Farm Family    7-May-17
# 21                    Mike M    6-Dec-17
# 22                 Bacon fan   15-Sep-17
# 23           Amazon Customer    4-Jul-17
# 24                FunMa of 3   11-Jul-17
# 25                   tj&mw67   14-Aug-17
# 26                   C. Chiu   10-Jun-15
# 27                      Jago    8-Jul-17
# 28                Jim Warren   26-Sep-17
# 29                      Drew    6-Feb-18
# ...                      ...         ...
# 1282           LOUIS  MCLEAN   10-Aug-17
# 1283         ROSALINDA MUNOZ   28-Aug-13
# 1284                    Troy   26-Jan-18
# 1285                    Roge   22-Jul-17
# 1286         Amazon Customer   20-Jan-18
# 1287                Hiten U.   21-Aug-17
# 1288         Daniel Salminen    3-Jul-17
# 1289         Michael simpson   10-Sep-17
# 1290                jon asri    5-Apr-18
# 1291                  zhuhuw    2-Feb-18
# 1292                   James   21-Aug-17
# 1293          Jimmylee Almen   22-Aug-17
# 1294                   Mark    25-Jun-17
# 1295                    dave   20-Nov-12
# 1296           Brian Leupold   11-Jun-15
# 1297       Critical Reviewer   15-Nov-12
# 1298        Barbara Levenson   10-Dec-12
# 1299                   kkjjn    3-Nov-12
# 1300            Daniel Avina   17-Mar-18
# 1301            Sara L Walls   29-Dec-17
# 1302          John D. Sissom   12-Apr-17
# 1303                     B A   11-Mar-18
# 1304               anonymous   14-Nov-17
# 1305                  Iceaug   22-Nov-12
# 1306                     MXN   13-Nov-17
# 1307                whiskers   28-Mar-13
# 1308                     MDD    9-Mar-18
# 1309            justsomedude   12-Dec-12
# 1310                 M. Ruse   17-Feb-13
# 1311         DidtheREASEARCH   29-Apr-13
# [1312 rows x 5 columns]

# %%
#cleaning the data frame to remove the unnecesary variables and words
df['rating']= df['rating'].str.extract('(\d+)', expand=True)
df['rating'].astype(int)
df['review_date']= pd.to_datetime(df['review_date'], format= "%d-%b-%y")
print(df['review_date'].sort_values())
# Out:
# 1299   2012-11-03
# 535    2012-11-05
# 1206   2012-11-06
# 1220   2012-11-07
# 720    2012-11-07
# 1252   2012-11-08
# 697    2012-11-08
# 991    2012-11-10
# 412    2012-11-10
# 709    2012-11-12
# 977    2012-11-13
# 1297   2012-11-15
# 256    2012-11-15
# 1195   2012-11-17
# 210    2012-11-18
# 1188   2012-11-18
# 409    2012-11-19
# 1047   2012-11-19
# 1295   2012-11-20
# 1217   2012-11-20
# 1172   2012-11-21
# 959    2012-11-21
# 1203   2012-11-21
# 1305   2012-11-22
# 942    2012-11-22
# 798    2012-11-22
# 1074   2012-11-24
# 924    2012-11-24
# 1144   2012-11-24
# 996    2012-11-24
#           ...
# 264    2018-04-10
# 209    2018-04-10
# 123    2018-04-11
# 133    2018-04-11
# 66     2018-04-11
# 405    2018-04-11
# 206    2018-04-11
# 287    2018-04-11
# 248    2018-04-12
# 807    2018-04-12
# 1018   2018-04-12
# 308    2018-04-12
# 318    2018-04-12
# 571    2018-04-12
# 815    2018-04-13
# 817    2018-04-13
# 378    2018-04-14
# 202    2018-04-14
# 138    2018-04-14
# 976    2018-04-14
# 128    2018-04-14
# 947    2018-04-14
# 346    2018-04-15
# 277    2018-04-15
# 418    2018-04-16
# 423    2018-04-16
# 62     2018-04-16
# 320    2018-04-16
# 105    2018-04-17
# 262    2018-04-17
# Name: review_date, Length: 1312, dtype: datetime64[ns]

# %%
#Filtering the data to get the values from 1 january 2017 until the day of scraping
mask = (df['review_date'] > '12-12-2016') & (df['review_date'] <= '15-4-2018')
df.loc[mask]
df = df.loc[mask]
#print(df)
print(df.head())
#creating a cleaned csv file
df.to_csv("Assignment_03.csv", sep=',')
# Out:
#                                                title  \
# 0  Quality made and a fantastic deal!  Let me sho...
# 1  Miniature in size & price, but big on light ou...
# 2                   Great for the kids while Camping
# 3                              Heavy Duty and Bright
# 4                                  Small, but mighty
#
#                                               review rating     author  \
# 0   These Rockbirds LED Flashlights I bought came...      5  GardenGuy
# 1  Given my many prior, poor experiences with sev...      4        NSB
# 2  Even though, the wide angle gives a decent spr...      3       Snax
# 3   These are good quality tactical flashlights. ...      5       jack
# 4  These ended up being very handy, but I didn't ...      4        JTL
#
#   review_date
# 0  2017-03-04
# 1  2018-02-10
# 2  2017-11-07
# 3  2017-03-07
# 4  2017-09-13

# %%
#Preprocessing: to evaluate the reviews in order to get the counter vectorized form for further analysis
review= df['review']
review.count()
cv = CountVectorizer(lowercase=True)
cv = CountVectorizer(lowercase=True, stop_words='english', ngram_range=(2, 2))
data = cv.fit_transform(review)
print(data)
print(cv.get_feature_names())
# Out:
#   (0, 3379)	1
#   (0, 3456)	1
#   (0, 2108)	1
#   (0, 6563)	1
#   (0, 5544)	1
#   (0, 2251)	1
#   (0, 5093)	1
#   (0, 6843)	1
#   (0, 3526)	1
#   (0, 664)	1
#   (0, 7448)	1
#   (0, 7536)	1
#   (0, 4741)	1
#   (0, 1276)	1
#   (0, 6783)	1
#   (0, 6845)	1
#   (0, 6378)	1
#   (0, 4836)	1
#   (0, 4153)	1
#   (0, 4732)	1
#   (0, 6007)	1
#   (0, 5644)	1
#   (0, 7450)	1
#   (0, 167)	1
#   (0, 569)	1
#   :	:
#   (835, 1153)	1
#   (835, 6862)	1
#   (835, 153)	1
#   (835, 1882)	1
#   (835, 2350)	1
#   (835, 481)	1
#   (835, 7551)	1
#   (836, 7267)	1
#   (836, 6162)	1
#   (836, 1941)	1
#   (836, 1061)	1
#   (836, 7164)	1
#   (837, 1848)	1
#   (837, 434)	1
#   (837, 1358)	1
#   (837, 3492)	1
#   (837, 3461)	1
#   (837, 7393)	1
#   (837, 7771)	1
#   (837, 7581)	1
#   (837, 3213)	1
#   (837, 772)	1
#   (837, 5782)	1
#   (837, 7739)	1
#   (837, 4861)	1
# ['00 price', '0yerto rico', '10 10', '10 amazing', '10 does', '10 dollars', '10 house', '10 love', '10 times', '100 dollar', '100 garbage', '100 lumens', '100 super', '100 time', '100 used', '100f power', '110lumens scratched', '12 99', '12 deep', '12 hours', '14 years', '14500 batteries', '14500 battery', '14500 li', '1aa battery', '1st arrived', '1st flashlight', '20 just', '20 like', '20 times', '200 lumen', '200 lumens', '2000 mah', '20min bike', '24 pack', '26 weather', '2a battery', '2nd light', '2nd review', '2nd set', '30 good', '30 right', '300 feet', '300 lumen', '300 lumens', '300lumens 200', '35 volts', '350 puts', '3aaa like', '3ft dirt', '3hrs strobe', '3rd time', '3wks light', '45 time', '4x wk', '50 50', '50 dosnt', '50 nuts', '50 yards', '5v small', '7v 800mah', '7v battery', '7v want', '7w led', '80 feet', '800mah led', '90 110lumens', '99 buys', '99 caveat', '99 crazy', '99 flashlight', '99 harbor', '99 maybe', '99 pack', '99 rechargeable', '99 time', 'aa alkaline', 'aa battary', 'aa batter', 'aa batteries', 'aa battery', 'aa bright', 'aa cell', 'aa flashlights', 'aa function', 'aa gives', 'aa pretty', 'aa size', 'aaa batteries', 'aaa battery', 'aaa puts', 'aaas strobe', 'ability broaden', 'ability change', 'ability different', 'ability focus', 'able actually', 'able belt', 'able carried', 'able charged', 'able open', 'able play', 'able remove', 'able silver', 'absolute junk', 'absolutely complaints', 'absolutely love', 'absolutely order', 'absolutely terrible', 'absolutely wonderful', 'abuse break', 'abuse son', 'accept replacement', 'access lights', 'account occasional', 'account wife', 'accurate durable', 'acknowledgement ps', 'activate normal', 'activated light', 'activated requires', 'activities kids', 'activities like', 'activities use', 'activity hunting', 'actual product', 'actually 300lumens', 'actually amazed', 'actually brightened', 'actually brighter', 'actually does', 'actually leash', 'actually producing', 'actually product', 'actually recently', 'actually second', 'actually surprised', 'actuates little', 'actuation point', 'ad says', 'add bug', 'added plus', 'addition buy', 'addition emergency', 'addition strobe', 'addition survival', 'adjust ability', 'adjust beam', 'adjust intensity', 'adjust length', 'adjust lens', 'adjust light', 'adjust scope', 'adjust tension', 'adjust turn', 'adjust want', 'adjustability beam', 'adjustable beam', 'adjustable bezel', 'adjustable close', 'adjustable compare', 'adjustable focus', 'adjustable lens', 'adjustable light', 'adjustable lighting', 'adjustable love', 'adjustable magnified', 'adjustable video', 'adjusted size', 'adjustment brightness', 'adjustment feature', 'adjustments durable', 'adjustments lastly', 'adjusts really', 'admit smaller', 'advantage shelf', 'advertised did', 'advertised handy', 'advertised issues', 'advertised likely', 'affiliated company', 'affordable like', 'afraid pry', 'afraid use', 'agitated customer', 'ago actually', 'ago suddenly', 'ahe bothered', 'ahe loses', 'ahead critters', 'aid kit', 'airsoft skirmish', 'al9ng batteries', 'alittle lighter', 'alkaline course', 'alkaline fully', 'alkalines nimh', 'allen screws', 'allow light', 'allow returns', 'allows attach', 'allows belt', 'allows east', 'allows quality', 'allows search', 'alot light', 'alot nicer', 'alot taking', 'aluminium lightweight', 'aluminium tube', 'aluminum battery', 'aluminum housing', 'aluminum lights', 'aluminum tough', 'amazed bright', 'amazed cool', 'amazed long', 'amazing 10', 'amazing car', 'amazing disappointed', 'amazing forever', 'amazing haven', 'amazing light', 'amazing little', 'amazing lowell', 'amazing portable', 'amazing value', 'amazingly bright', 'amazingly good', 'amazingness bright', 'amazon basics', 'amazon customer', 'amazon deals', 'amazon indication', 'amazon just', 'amazon prime', 'amazon product', 'amazon rechargeable', 'amazon returned', 'amazonbasic aa', 'angle gives', 'angle stopped', 'angle wish', 'animals bright', 'annoying great', ' ...

# %%
def noun_adj_verb_filter(sentences):

    preprocessed_sentences = []
    keep_types = {'NOUN', 'PROPN', 'ADJ', 'VERB'}

    for sentence in sentences:
        doc = nlp(sentence)

        keep_tokens_string = ' '.join([t.text for t in doc if t.pos_ in keep_types])
        preprocessed_sentences.append(keep_tokens_string)

    return preprocessed_sentences

# %%
preproc_sents = noun_adj_verb_filter(df['review'])
print(preproc_sents)

cv = CountVectorizer(lowercase=True, stop_words='english',)
data1 = cv.fit_transform(preproc_sents)
print(data.toarray())
print(cv.get_feature_names())

#evaluating the length of review and plotting it for available observations
text_length = df['review'].apply(len)
print(df['text_length'].describe())
plt.hist(text_length)
plt.xlabel("review length")
plt.ylabel("Number of reviews")
plt.show()

plt.scatter(y_test, predictions)
plt.xlabel('Actual Value')
plt.ylabel('Predicted')
plt.show()

# %%
#splitting the data into training and test set(of reviews and ratings)
y= df['rating']
X_train, X_test, y_train, y_test = train_test_split(data1, y, test_size=0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape )

#regression analysis of reviews against the reviews
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
print(predictions)
# Out:
# (670, 1933) (670,)
# (168, 1933) (168,)
# [ 6.55074893  5.56341462  1.73791468  5.00000007  5.12020613  3.99309083
#   6.38356116  3.6717593   3.14943244  4.14829448  5.63324274  1.99188678
#   2.04643075  3.64051649 -3.53645374  5.05684214  4.9943629   4.69975348
#   7.59708283  3.87467123 -1.10433277  8.10711147  1.81830821 -1.70536958
#   0.41614817  4.5315322   2.83463226  5.20166698  2.85164531  6.77660694
#   4.61737108  9.4535195   4.70734541  4.74418723  3.39723388  4.78513902
#   4.70585426  8.01539057  7.18991595  2.77487075  2.99784191  4.57105594
#   5.31179737  4.44938176  5.147835    4.74198908  3.71476977  6.99069362
#   4.489124    6.27952138  4.78513902  7.70173468  1.99188678  3.4734515
#   5.00000044  4.62907317  4.69929299  4.87874517  4.39791124 -1.42333463
#   4.74418723  4.99999959  4.09801043  5.29998846  2.16081084  2.98309349
#   6.90722496  3.64389537  4.69003526 -2.10809947  4.78289948  4.17364657
#   4.99999999  4.75300544  2.34810126  2.86146838  1.82778013  1.21170426
#   4.69975348  5.69409795  3.141425   11.33457641  4.71810471  4.39414512
#   9.0932094   4.35935006  4.4459267  -4.41954827  3.59656435  3.62557692
#   4.68870592  6.58420632  4.19583358  6.38356116  4.88423378  4.69975348
#   1.84655705 -1.36912954  6.02701264  4.25523071  4.489124    1.00000009
#   4.67908903  1.92096503  4.19104478  4.99999991  4.8793285   6.65408923
#  21.91667664  2.6721111   4.98688287  1.00000011  4.4619261   3.27557786
#   9.16160359  6.29906247  4.25290462  3.13474294  6.75551334  2.79024127
#   4.81995962  4.65814675 -2.68732275  0.70286794  6.58420632  5.44390245
#   4.08121091  2.33974231  6.4682249   3.90223236  6.80938086  4.10171609
#   5.00000005  0.29836158  5.1765443  -0.7396544   3.83628534  5.8697333
#   5.09565946  4.489124    4.92545765  3.00000039  5.74976943  3.22437245
#   7.97405042  4.78513902  6.53906369 -0.79935461  9.25576835  4.89981816
#   0.13222643  3.40298656  4.81328207  1.19624156  7.12364119  5.78357424
#   2.15524838  4.489124    4.96275267  6.67061297  7.21104995  4.27389845
#   5.61152076  3.93580326  8.52706229  5.70808533  1.20058483  4.70249756]

# %%
#randomforest classification
rf= RandomForestClassifier()
scores = cross_validate(rf, data1, y, cv=10, n_jobs=-1, return_train_score=True)
print(scores)
# Out:
# {'fit_time': array([0.28275204, 0.32586646, 0.3228581 , 0.53893328, 0.48278403,
#        0.47877312, 0.48027754, 0.4151032 , 0.40557742, 0.40607953]), 'score_time': array([0.00451255, 0.00451207, 0.00651932, 0.00451231, 0.00401211,
#        0.00401139, 0.00351024, 0.00401211, 0.00401211, 0.00451326]), 'test_score': array([0.63953488, 0.63953488, 0.68604651, 0.64285714, 0.67857143,
#        0.66666667, 0.6626506 , 0.68292683, 0.70731707, 0.59259259]), 'train_score': array([0.97340426, 0.98005319, 0.97340426, 0.98143236, 0.98275862,
#        0.97745358, 0.98013245, 0.97883598, 0.97354497, 0.98546896])}

# %%
#Modelling
#Model 1: Multinomial Naive Bayes
model = MultinomialNB()
model.fit(data1, y)
predictionsNB = model.predict(X_test)
#print(predictionsNB)
print(accuracy_score(y_test, predictionsNB, normalize= True))
# Out:
# 0.8214285714285714

# %%
#Model 2: Support Vector Machine Algorithm
model2 = svm.LinearSVC()
model2_fit= model2.fit(data1, y)
#model2.score(data1, y)
predictedSVM = model2.predict(X_test)
print(predictedSVM)
print(accuracy_score(y_test, predictedSVM, normalize= True))
# Out:
# ['5' '3' '1' '5' '5' '5' '5' '5' '5' '1' '5' '5' '1' '5' '1' '5' '5' '5'
#  '3' '5' '5' '4' '5' '5' '3' '5' '4' '5' '5' '2' '4' '5' '4' '5' '5' '5'
#  '4' '5' '5' '2' '1' '5' '5' '4' '5' '5' '5' '2' '5' '5' '5' '5' '5' '1'
#  '5' '5' '2' '5' '2' '1' '5' '5' '4' '5' '1' '5' '5' '5' '5' '1' '4' '1'
#  '5' '5' '5' '5' '5' '1' '5' '5' '4' '5' '5' '5' '5' '5' '5' '1' '5' '5'
#  '5' '5' '5' '5' '5' '5' '5' '1' '5' '5' '5' '1' '5' '5' '5' '5' '5' '5'
#  '2' '5' '4' '1' '5' '1' '5' '5' '2' '5' '1' '3' '5' '5' '5' '4' '5' '3'
#  '5' '3' '4' '4' '5' '5' '5' '5' '5' '1' '5' '5' '5' '5' '5' '3' '5' '2'
#  '5' '5' '5' '4' '4' '5' '2' '5' '5' '1' '4' '2' '2' '5' '5' '5' '4' '5'
#  '5' '4' '5' '5' '5' '3']
# 0.9583333333333334
